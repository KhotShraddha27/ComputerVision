# %% [markdown]
# <a href="https://colab.research.google.com/github/KhotShraddha27/ComputerVision/blob/main/cv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import sys
from google.colab.patches import cv2_imshow
import os

image_path="/content/drive/MyDrive/opencv/COLOR.jpg"

if not os.path.exists(image_path):
  print(f"Error: image file not found at {image_path}")
else:
  img = cv.imread(image_path)
  if img is None:
    print(f"Error: could not read image from {image_path}")
  else:
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
from google.colab import drive
drive.mount('/content/drive')
# import the required library
import cv2
from google.colab.patches import cv2_imshow # Import cv2_imshow

# read the input image
image = cv2.imread('/content/drive/MyDrive/opencv/opcv.jpg')

# define the alpha and beta
alpha = 1.0 # Contrast control
beta = 2 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# display the output image
cv2_imshow(adjusted)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
import cv2
from google.colab.patches import cv2_imshow
import sys # Import sys to exit if image loading fails

# Load an image
image_path = '/content/drive/MyDrive/opencv/blur.jpg' # Define the image path
image = cv2.imread(image_path)

# Add a check to see if the image was loaded successfully
if image is None:
    sys.exit(f"Error: Could not read the image from {image_path}")


# Apply Gaussian blur with specific sigma values
# A symmetrical blur (sigmaX=3, sigmaY=3 implicitly)
blurred_image_1 = cv2.GaussianBlur(image, (5, 5), 10)

# Anisotropic blur (more blur in X than Y)
blurred_image_2 = cv2.GaussianBlur(image, (5, 5), 5, 1)

# Blur with sigma calculated from kernel size
blurred_image_3 = cv2.GaussianBlur(image, (5, 5), 0)

# Display the images (optional)
cv2_imshow(image)
cv2_imshow(blurred_image_1)
cv2_imshow(blurred_image_2)
cv2_imshow(blurred_image_3)
# cv2.waitKey(0) # waitKey and destroyAllWindows are not needed with cv2_imshow
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x681>
# <PIL.Image.Image image mode=RGB size=1024x681>
# <PIL.Image.Image image mode=RGB size=1024x681>
# <PIL.Image.Image image mode=RGB size=1024x681>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/opencv/mona.webp')

median = cv2.medianBlur(img,3)
#bilateral = cv2.bilateralFilter(img, 9, 75, 75)


# Display original and blurred images using cv2_imshow
cv2_imshow(img)
cv2_imshow(median)
#cv2_imshow(bilateral)
# Out:
# <PIL.Image.Image image mode=RGB size=375x561>
# <PIL.Image.Image image mode=RGB size=375x561>
